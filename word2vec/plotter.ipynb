# %%
from csv import reader
import numpy as np
from sklearn.manifold import TSNE

from matplotlib import pyplot as plt
from plotly.offline import init_notebook_mode, iplot
from plotly.graph_objs import Scatter, Layout, Figure

init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
ls = []
with open("/home/local/saska/Documents/fastt/vecs.txt") as inp:
    rd = reader(inp, delimiter=" ")
    for l in rd:
        if len(l) == 102:
            ls.append((l[0], np.asarray(l[1:-1], dtype=np.float32)))

# %%
model = TSNE(n_components=2, verbose=2)
x2d = model.fit_transform([x[1] for x in ls])
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 1917 samples in 0.007s...
# [t-SNE] Computed neighbors for 1917 samples in 0.757s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1917
# [t-SNE] Computed conditional probabilities for sample 1917 / 1917
# [t-SNE] Mean sigma: 1.625634
# [t-SNE] Computed conditional probabilities in 0.114s
# [t-SNE] Iteration 50: error = 97.7111969, gradient norm = 0.1804055 (50 iterations in 2.937s)
# [t-SNE] Iteration 100: error = 99.6835938, gradient norm = 0.1446579 (50 iterations in 2.735s)
# [t-SNE] Iteration 150: error = 99.4896317, gradient norm = 0.1690655 (50 iterations in 2.733s)
# [t-SNE] Iteration 200: error = 100.5160294, gradient norm = 0.1708702 (50 iterations in 2.477s)
# [t-SNE] Iteration 250: error = 102.0424576, gradient norm = 0.1464339 (50 iterations in 2.584s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 102.042458
# [t-SNE] Iteration 300: error = 2.7444901, gradient norm = 0.0038277 (50 iterations in 2.098s)
# [t-SNE] Iteration 350: error = 2.4013550, gradient norm = 0.0012883 (50 iterations in 2.045s)
# [t-SNE] Iteration 400: error = 2.2339702, gradient norm = 0.0007622 (50 iterations in 2.046s)
# [t-SNE] Iteration 450: error = 2.1513925, gradient norm = 0.0004464 (50 iterations in 2.036s)
# [t-SNE] Iteration 500: error = 2.0822988, gradient norm = 0.0002936 (50 iterations in 1.995s)
# [t-SNE] Iteration 550: error = 2.0679722, gradient norm = 0.0001791 (50 iterations in 1.990s)
# [t-SNE] Iteration 600: error = 2.0580029, gradient norm = 0.0001511 (50 iterations in 1.986s)
# [t-SNE] Iteration 650: error = 2.0507309, gradient norm = 0.0001568 (50 iterations in 1.986s)
# [t-SNE] Iteration 700: error = 2.0449355, gradient norm = 0.0001261 (50 iterations in 1.986s)
# [t-SNE] Iteration 750: error = 2.0401387, gradient norm = 0.0001219 (50 iterations in 1.980s)
# [t-SNE] Iteration 800: error = 2.0359321, gradient norm = 0.0001439 (50 iterations in 1.996s)
# [t-SNE] Iteration 850: error = 2.0309026, gradient norm = 0.0001412 (50 iterations in 1.978s)
# [t-SNE] Iteration 900: error = 2.0281074, gradient norm = 0.0000950 (50 iterations in 1.975s)
# [t-SNE] Iteration 950: error = 2.0256345, gradient norm = 0.0000884 (50 iterations in 1.980s)
# [t-SNE] Iteration 1000: error = 2.0234249, gradient norm = 0.0000941 (50 iterations in 1.993s)
# [t-SNE] Error after 1000 iterations: 2.023425

# %%
data = Scatter(x=[x[0] for x in x2d], y=[y[1] for y in x2d], text=[t[0] for t in ls], mode='markers')
layout = Layout(hovermode='closest')
fig = Figure(data=[data], layout=layout)
iplot(fig)
# Out:
# <div id="321458c3-63b8-4fee-929f-394fba3525fd" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("321458c3-63b8-4fee-929f-394fba3525fd", [{"text": ["ja", "on", "ei", "mutta", "hyv\u00e4", "hyvin", "ett\u00e4", "ole", "kun", "toimii", "oli", "my\u00f6s", "kuin", "se", "niin", "jos", "t\u00e4m\u00e4", "voi", "en", "todella", "saa", "sen", "kanssa", "ovat", "ihan", "joka", "tai", "ollut", "olen", "helppo", "t\u00e4m\u00e4n", "eritt\u00e4in", "hieman", "#", "eik\u00e4", "laite", "joten", "olla", "suosittelen", "vaikka", "j\u00e4lkeen", "tuote", "nyt", "viel\u00e4", "vain", "-", "kyll\u00e4", "##", "mukana", "ostin", "k\u00e4ytt\u00e4\u00e4", "v\u00e4h\u00e4n", "paljon", "mit\u00e4\u00e4n", "koska", "k\u00e4yt\u00f6ss\u00e4", "pit\u00e4\u00e4", "kuitenkin", "tulee", "sit\u00e4", "jo", "itse", "olisi", "mit\u00e4", "eli", "kaikki", "esim", "helposti", "sek\u00e4", "ilman", "kiinni", "hinta", "t\u00e4t\u00e4", "t\u00e4ss\u00e4", "t\u00e4h\u00e4n", "aika", "ainakin", "sitten", "muuten", "laitteen", "vaan", "aivan", "koko", "tyytyv\u00e4inen", "juuri", "toimiva", "pieni", "t\u00e4ll\u00e4", "tuntuu", "liian", "kuten", "siit\u00e4", "puhelimen", "eiv\u00e4t", "ehk\u00e4", "aina", "kuulokkeet", "laatu", "siis", "nopeasti", "sill\u00e4", "toimi", "sopii", "ainoa", "tosin", "lis\u00e4ksi", "puhelin", "oikein", "kone", "pois", "tuli", "mik\u00e4", "erinomainen", "ok", "n\u00e4ytt\u00f6", "ne", "###", "kannattaa", "siihen", "k\u00e4ytt\u00f6\u00f6n", "tuotteen", "voisi", "enemm\u00e4n", "miinus", "jossa", "nopea", "eri", "l\u00f6ytyy", "mielest\u00e4ni", "melko", "noin", "toiminut", "laadukas", "mukaan", "\u00e4\u00e4ni", "n\u00e4m\u00e4", "kest\u00e4\u00e4", "v\u00e4lill\u00e4", "k\u00e4yt\u00f6n", "tosi", "pysyy", "tarvitse", "siin\u00e4", "tekee", "heti", "jopa", "verrattuna", "t\u00e4st\u00e4", "en\u00e4\u00e4", "parempi", "riitt\u00e4\u00e4", "ongelmia", "ettei", "ottaa", "hyv\u00e4t", "akku", "n\u00e4hden", "helppoa", "t\u00e4ysin", "n\u00e4yt\u00f6n", "kaksi", "jonka", "tuo", "jotka", "kamera", "p\u00e4\u00e4lle", "ennen", "iso", "loistava", "asennus", "\u00e4\u00e4nenlaatu", "edes", "yksi", "kautta", "+", "pari", "kotelo", "n\u00e4in", "verran", "toki", "kameran", "asentaa", "kevyt", "hyv\u00e4\u00e4", "koneen", "muutaman", "hiljainen", "tullut", "ostaa", "olevan", "oloinen", "muuta", "mukava", "menee", "takia", "laittaa", "suositella", "n\u00e4ytt\u00e4\u00e4", "hyv\u00e4n", "minulla", "sain", "n\u00e4it\u00e4", "akun", "lis\u00e4\u00e4", "k\u00e4tev\u00e4", "mahtuu", "sanoa", "toinen", "toimivat", "varten", "suoraan", "riitt\u00e4v\u00e4n", "paras", "vuoden", "plussaa", "voin", "silti", "k\u00e4ytt\u00e4nyt", "laadukkaan", "vaikuttaa", "niit\u00e4", "yli", "hintaan", "paremmin", "sopivan", "viikon", "j\u00e4\u00e4", "antaa", "####", "varsin", "varmasti", "l\u00e4hes", "peli", "kuva", "kovin", "ostos", "jotta", "aikaa", "kuukauden", "tuotetta", "hiiri", "sopiva", "samalla", "vuotta", "jotain", "huomattavasti", "k\u00e4ytt\u00f6", "vaatii", "hiukan", "kokoinen", "tyylik\u00e4s", "ajan", "piti", "haluaa", "saanut", "yht\u00e4", "edullinen", "ongelma", "johto", "kaapeli", "varsinkin", "n", "alle", "oma", "tarpeeksi", "ainakaan", "sai", "helppok\u00e4ytt\u00f6inen", "uuden", "kuvan", "pit\u00e4\u00e4kin", "k\u00e4yt\u00e4n", "huono", "kerran", "saada", "taas", "usb", "kertaa", "k\u00e4ytt\u00f6\u00f6notto", "tilaa", "kaiken", "jolloin", "esimerkiksi", "mm", "suojaa", "saisi", "p\u00e4\u00e4ss\u00e4", "avulla", "laitetta", "kotelon", "p\u00e4\u00e4ll\u00e4", "\u00e4\u00e4nen", "vanha", "jolla", "kuitenkaan", "k\u00e4ytt\u00f6\u00e4", "saattaa", "vuoksi", "miten", "meni", "pit\u00e4isi", "tuntuinen", "yll\u00e4tt\u00e4v\u00e4n", "verkkokauppa", "aikana", "ehdottomasti", "hienosti", "perus", "windows", "onneksi", "ajaa", "jota", "omaan", "alkaa", "onnistuu" ...
